# %% [markdown]
# 6.	Train a decision tree and a randomforest from the scikit-learn package for outcome label prediction using the event log created at step 2 and and step 5 for prefix length L=2 and L=5.  Split 70-30 for training-testing.
#
# Hyperparameters
# DT: max_depth=5
# RF: n_estimators=100, oob_score=True

# %%
#step 2 decision tree
import pandas as pd
import numpy as np

from sklearn import datasets
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
log_bpic = pd.read_csv("log_bpic.csv", index_col=0)
log_bpic
# Out:
#                  caseid                  activity                       ts  \
# 0       Offer_247135719            O_Create Offer  2016/01/02 18:17:05.720
# 1       Offer_247135719                 O_Created  2016/01/02 18:17:08.762
# 2       Offer_247135719      O_Sent (online only)  2016/01/02 18:19:21.330
# 3       Offer_247135719               O_Cancelled  2016/01/02 18:21:26.034
# 4       Offer_941964966            O_Create Offer  2016/01/02 18:21:42.022
# ...                 ...                       ...                      ...
# 22404  Offer_1064426652            O_Create Offer  2016/02/18 22:50:01.446
# 22405  Offer_1064426652                 O_Created  2016/02/18 22:50:02.655
# 22406  Offer_1064426652  O_Sent (mail and online)  2016/02/18 22:50:22.174
# 22407  Offer_1064426652                O_Returned  2016/02/29 19:08:56.200
# 22408  Offer_1064426652                O_Accepted  2016/02/29 23:43:45.831
#
#        resource  outcome
# 0       User_17     True
# ...

# %%
bpic_data = log_bpic[["caseid", "activity", "ts", "resource"]]
bpic_data
# Out:
#                  caseid                  activity                       ts  \
# 0       Offer_247135719            O_Create Offer  2016/01/02 18:17:05.720
# 1       Offer_247135719                 O_Created  2016/01/02 18:17:08.762
# 2       Offer_247135719      O_Sent (online only)  2016/01/02 18:19:21.330
# 3       Offer_247135719               O_Cancelled  2016/01/02 18:21:26.034
# 4       Offer_941964966            O_Create Offer  2016/01/02 18:21:42.022
# ...                 ...                       ...                      ...
# 22404  Offer_1064426652            O_Create Offer  2016/02/18 22:50:01.446
# 22405  Offer_1064426652                 O_Created  2016/02/18 22:50:02.655
# 22406  Offer_1064426652  O_Sent (mail and online)  2016/02/18 22:50:22.174
# 22407  Offer_1064426652                O_Returned  2016/02/29 19:08:56.200
# 22408  Offer_1064426652                O_Accepted  2016/02/29 23:43:45.831
#
#        resource
# 0       User_17
# 1       User_17
# ...

# %%
#one-hot encoding 여기서부터 해야함!!!!!!!!!!!!!!!!!!!!
#https://injo.tistory.com/11

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(bpic_data)
labels = encoder.transform(bpic_data)
labels = labels.reshape(-1,1)

print('인코딩 변화값: ', labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 8
#       5 from sklearn.preprocessing import LabelEncoder
#       7 encoder = LabelEncoder()
# ----> 8 encoder.fit(bpic_data)
#       9 labels = encoder.transform(bpic_data)
#      10 labels = labels.reshape(-1,1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\preprocessing\_label.py:98, in LabelEncoder.fit(self, y)
#      85 def fit(self, y):
#      86     """Fit label encoder.
#      87
#      88     Parameters
#    (...)
#      96         Fitted label encoder.
#      97     """
# ---> 98     y = column_or_1d(y, warn=True)
#      99     self.classes_ = _unique(y)
#     100     return self
#
# ...

# %%
#1d array로 만드려고.. 하나하나 bpic_data에 있는거 나누기 (컬럼 1개씩)

# %%
X_train, X_test, y_train, y_test = train_test_split(bpic_data, bpic_target, test_size=0.3, random_state=10)

# %%
step2_model_dt = DecisionTreeClassifier(max_depth = 5)

# %%
step2_model_dt.fit(X_train, y_train)

print("train score: {:.3f}".format(step2_model_dt.score(X_train, y_train)))

print("test score: {:.3f}".format(step2_model_dt.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 step2_model_dt.fit(X_train, y_train)
#       3 print("train score: {:.3f}".format(step2_model_dt.score(X_train, y_train)))
#       5 print("test score: {:.3f}".format(step2_model_dt.score(X_test, y_test)))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
# ...

# %%
#how to use string data in scikit-learn DT
# one-hot-encoding
#https://datascience.stackexchange.com/questions/5226/strings-as-features-in-decision-tree-random-forest

# %%
#step 5 for prefix length L=2 and L=5
